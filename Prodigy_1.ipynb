# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=pd.read_csv('age_gender.csv')
x
# Out:
#       age  ethnicity  gender                        img_name  \
# 0       1          2       0  20161219203650636.jpg.chip.jpg
# 1       1          2       0  20161219222752047.jpg.chip.jpg
# 2       1          2       0  20161219222832191.jpg.chip.jpg
# 3       1          2       0  20161220144911423.jpg.chip.jpg
# 4       1          2       0  20161220144914327.jpg.chip.jpg
# ...   ...        ...     ...                             ...
# 1543   13          0       1  20170109214425620.jpg.chip.jpg
# 1544   13          3       1  20170109205242338.jpg.chip.jpg
# 1545   13          0       1  20170109201615837.jpg.chip.jpg
# 1546   13          0       1  20170109212934682.jpg.chip.jpg
# 1547   13          0       1  20170104005742384.jpg.chip.jpg
#
#                                                  pixels
# 0     129 128 128 126 127 130 133 135 139 142 145 14...
# 1     164 74 111 168 169 171 175 182 184 188 193 199...
# 2     67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3     193 197 198 200 199 200 202 203 204 205 208 21...
# 4     202 205 209 210 209 209 210 211 212 214 218 21...
# ...                                                 ...
# 1543  23 10 4 1 4 15 39 59 78 91 98 106 112 121 127 ...
# 1544  112 49 56 51 45 41 43 48 53 70 85 85 86 87 89 ...
# 1545  77 54 34 26 32 41 70 96 105 116 125 129 135 14...
# 1546  100 108 110 110 116 123 129 163 162 152 143 19...
# 1547  142 149 127 98 93 96 103 116 131 141 148 158 1...
#
# [1548 rows x 5 columns]

# %%
x.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
x.tail()
# Out:
#       age  ethnicity  gender                        img_name  \
# 1543   13          0       1  20170109214425620.jpg.chip.jpg
# 1544   13          3       1  20170109205242338.jpg.chip.jpg
# 1545   13          0       1  20170109201615837.jpg.chip.jpg
# 1546   13          0       1  20170109212934682.jpg.chip.jpg
# 1547   13          0       1  20170104005742384.jpg.chip.jpg
#
#                                                  pixels
# 1543  23 10 4 1 4 15 39 59 78 91 98 106 112 121 127 ...
# 1544  112 49 56 51 45 41 43 48 53 70 85 85 86 87 89 ...
# 1545  77 54 34 26 32 41 70 96 105 116 125 129 135 14...
# 1546  100 108 110 110 116 123 129 163 162 152 143 19...
# 1547  142 149 127 98 93 96 103 116 131 141 148 158 1...

# %%
x.shape
# Out:
# (1548, 5)

# %%
print("No.of Rows: {}".format(len(x)))
print("No.of Columns: {}".format(len(x.columns)))
# Out:
# No.of Rows: 1548
# No.of Columns: 5

# %%
# Bar graph for Age Distribution
age_dist = x['age'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(age_dist.index, age_dist.values, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Bar graph for Gender Distribution
gender_dist = x['gender'].value_counts().rename(index={0: 'Male', 1: 'Female'})
plt.figure(figsize=(8, 6))
plt.bar(gender_dist.index, gender_dist.values, color='pink')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Bar graph for Ethnicity Distribution
ethnicity_dist = x['ethnicity'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(ethnicity_dist.index, ethnicity_dist.values, color='lightgreen')
plt.title('Ethnicity Distribution')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for Age
plt.figure(figsize=(10, 6))
plt.hist(x['age'], bins=20, color='green', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
